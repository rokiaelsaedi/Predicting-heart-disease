# %%
# import libraries
from xgboost import XGBRegressor
import numpy as np
import seaborn as sns
from sklearn import metrics
import tkinter as tk
from tkinter import *
from tkinter import filedialog
from tkinter.filedialog import askopenfilename
from sklearn.feature_selection import RFE
import matplotlib.pyplot as plt
from sklearn.svm import SVR
from sklearn.svm import SVC
from sklearn import svm
import pandas as pd
import os
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from tkinter import messagebox
from matplotlib.figure import Figure 
from matplotlib.backends.backend_tkagg import (FigureCanvasTkAgg,  
NavigationToolbar2Tk) 
from PIL import ImageTk, Image
from string import ascii_letters
from typing import Callable

# %%
# loading the data from csv file to a Pandas DataFrame
data = pd.read_csv('heart.csv')
# print the first 5 rows of the dataframe
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
# checking the number of rows and columns
data.shape
# Out:
# (1025, 14)

# %%
# getting some informations about the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
# checking for missing values
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
myframe = Tk()
myframe.title("Heart Disease")
myframe.geometry("800x600")
my_font1=('times', 18, 'bold')

# %%
def hplot():
    new1=Toplevel(myframe)
    new1.geometry("800x750")
    new1.title("plot1")
    def init_gui(new1, update_function: Callable) -> FigureCanvasTkAgg:
        def event_key_press(event):
            print("you pressed {}".format(event.key))
            update_function()
            key_press_handler(event, canvas)

    # create empty figure and draw
        init_figure = create_figure()
        canvas = FigureCanvasTkAgg(init_figure, master=new1)
        canvas.draw()
        canvas.get_tk_widget().pack(side=tk.TOP, fill=tk.BOTH, expand=1)
    # call key press event
        canvas.mpl_connect("key_press_event", event_key_press)
        return canvas


    def create_figure() -> Figure:
        df = pd.read_csv("heart.csv")
    # plot the data
        figure = Figure(figsize=(3, 3))
        ax = figure.subplots()
        sns.heatmap(df.corr(), square=True, cbar=False, ax=ax)
        return figure


    def redraw_figure():
        figure = create_figure()
        canvas.figure = figure
        canvas.draw()


    sns.set()
    #new1 = Tk()
    canvas = init_gui(new1, update_function=redraw_figure)
   # pop.mainloop()

def sexplot():
    new1=Toplevel(myframe)
    new1.geometry("800x750")
    new1.title("plot2")
    def init_gui(new1, update_function: Callable) -> FigureCanvasTkAgg:
        def event_key_press(event):
            print("you pressed {}".format(event.key))
            update_function()
            key_press_handler(event, canvas)

    # create empty figure and draw
        init_figure = create_figure()
        canvas = FigureCanvasTkAgg(init_figure, master=new1)
        canvas.draw()
        canvas.get_tk_widget().pack(side=tk.TOP, fill=tk.BOTH, expand=1)
    # call key press event
        canvas.mpl_connect("key_press_event", event_key_press)
        return canvas


    def create_figure() -> Figure:
        df = pd.read_csv("heart.csv")
    # plot the data
        figure = Figure(figsize=(3, 3))
        ax = figure.subplots()
        sns.countplot(x="target", data=df,hue = 'sex',ax=ax).set_title("GENDER - Heart Diseases")
        return figure


    def redraw_figure():
        figure = create_figure()
        canvas.figure = figure
        canvas.draw()


    sns.set()
    #new1 = Tk()
    canvas = init_gui(new1, update_function=redraw_figure)
   # pop.mainloop()   

def resplot():
    new1=Toplevel(myframe)
    new1.geometry("800x750")
    new1.title("plot3")
    def init_gui(new1, update_function: Callable) -> FigureCanvasTkAgg:
        def event_key_press(event):
            print("you pressed {}".format(event.key))
            update_function()
            key_press_handler(event, canvas)

    # create empty figure and draw
        init_figure = create_figure()
        canvas = FigureCanvasTkAgg(init_figure, master=new1)
        canvas.draw()
        canvas.get_tk_widget().pack(side=tk.TOP, fill=tk.BOTH, expand=1)
    # call key press event
        canvas.mpl_connect("key_press_event", event_key_press)
        return canvas


    def create_figure() -> Figure:
        df = pd.read_csv("heart.csv")
    # plot the data
        figure = Figure(figsize=(3, 3))
        ax = figure.subplots()
        temp = (df.groupby(['target']))['restecg'].value_counts(normalize=True).mul(100).reset_index(name = "percentage")
        sns.barplot(x = "target", y = "percentage", hue = "restecg", data = temp,ax=ax).set_title("resting electrocardiographic results vs Heart Disease")
        return figure


    def redraw_figure():
        figure = create_figure()
        canvas.figure = figure
        canvas.draw()


    sns.set()
    #new1 = Tk()
    canvas = init_gui(new1, update_function=redraw_figure)
   # pop.mainloop()   

def caplot():
    new1=Toplevel(myframe)
    new1.geometry("800x750")
    new1.title("plot4")
    def init_gui(new1, update_function: Callable) -> FigureCanvasTkAgg:
        def event_key_press(event):
            print("you pressed {}".format(event.key))
            update_function()
            key_press_handler(event, canvas)

    # create empty figure and draw
        init_figure = create_figure()
        canvas = FigureCanvasTkAgg(init_figure, master=new1)
        canvas.draw()
        canvas.get_tk_widget().pack(side=tk.TOP, fill=tk.BOTH, expand=1)
    # call key press event
        canvas.mpl_connect("key_press_event", event_key_press)
        return canvas


    def create_figure() -> Figure:
        df = pd.read_csv("heart.csv")
    # plot the data
        figure = Figure(figsize=(3, 3))
        ax = figure.subplots()
        temp = (df.groupby(['target']))['ca'].value_counts(normalize=True).mul(100).reset_index(name = "percentage")
        sns.barplot(x = "target", y = "percentage", hue = "ca", data = temp,ax=ax).set_title("ca vs Heart Disease")
        return figure


    def redraw_figure():
        figure = create_figure()
        canvas.figure = figure
        canvas.draw()


    sns.set()
    #new1 = Tk()
    canvas = init_gui(new1, update_function=redraw_figure)
   # pop.mainloop()   

def fbsplot():
    new1=Toplevel(myframe)
    new1.geometry("800x750")
    new1.title("plot5")
    def init_gui(new1, update_function: Callable) -> FigureCanvasTkAgg:
        def event_key_press(event):
            print("you pressed {}".format(event.key))
            update_function()
            key_press_handler(event, canvas)

    # create empty figure and draw
        init_figure = create_figure()
        canvas = FigureCanvasTkAgg(init_figure, master=new1)
        canvas.draw()
        canvas.get_tk_widget().pack(side=tk.TOP, fill=tk.BOTH, expand=1)
    # call key press event
        canvas.mpl_connect("key_press_event", event_key_press)
        return canvas


    def create_figure() -> Figure:
        df = pd.read_csv("heart.csv")
    # plot the data
        figure = Figure(figsize=(3, 3))
        ax = figure.subplots()
        temp = (df.groupby(['target']))['fbs'].value_counts(normalize=True).mul(100).reset_index(name = "percentage")
        sns.barplot(x = "target", y = "percentage", hue = "fbs", data = temp,ax=ax).set_title("FBS vs Target")
        return figure


    def redraw_figure():
        figure = create_figure()
        canvas.figure = figure
        canvas.draw()


    sns.set()
    #new1 = Tk()
    canvas = init_gui(new1, update_function=redraw_figure)
   # pop.mainloop()   

def chplot():
    new1=Toplevel(myframe)
    new1.geometry("800x750")
    new1.title("plot6")
    def init_gui(new1, update_function: Callable) -> FigureCanvasTkAgg:
        def event_key_press(event):
            print("you pressed {}".format(event.key))
            update_function()
            key_press_handler(event, canvas)

    # create empty figure and draw
        init_figure = create_figure()
        canvas = FigureCanvasTkAgg(init_figure, master=new1)
        canvas.draw()
        canvas.get_tk_widget().pack(side=tk.TOP, fill=tk.BOTH, expand=1)
    # call key press event
        canvas.mpl_connect("key_press_event", event_key_press)
        return canvas


    def create_figure() -> Figure:
        df = pd.read_csv("heart.csv")
    # plot the data
        figure = Figure(figsize=(3, 3))
        ax = figure.subplots()
        temp = (df.groupby(['target']))['cp'].value_counts(normalize=True).mul(100).reset_index(name = "percentage")
        sns.barplot(x = "target", y = "percentage", hue = "cp", data = temp,ax=ax).set_title("Chest Pain vs Heart Disease")
        return figure


    def redraw_figure():
        figure = create_figure()
        canvas.figure = figure
        canvas.draw()


    sns.set()
    #new1 = Tk()
    canvas = init_gui(new1, update_function=redraw_figure)
   # pop.mainloop()   
    
    
    
    
    
    
  
   
###########################################################################################    
def linear_regression():
    new=Toplevel(myframe)
    new.geometry("800x750")
    new.title("linear regression")
    def data():
        global df
        global check
        filename = askopenfilename(initialdir='C:/Users/Softlaptop/ML project',title = "Select file") 
        check = StringVar()
        check = "Dataset is uploaded"
        file = open(filename, 'r')
        t_upload.insert(END, check)
        df = pd.read_csv(filename)
    def train_data():
    
        testSize=float(splitEntry.get())
        
    
        try:
            testSize=float(splitEntry.get())

        except ValueError:
            print('Test Size value is not a float')
        if attribute_selection.get()=="hold_out_method":
            X = df.iloc[:,:-1]
            y = df.iloc[:,-1]
            
            
            global X_train, X_test, y_train, y_test 
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=testSize, random_state=42)
    
            global model
            model=LinearRegression()
            model.fit(X_train,y_train)
            error_message = " train is done"
            t_train.delete("1.0", "end")
            t_train.insert(END, error_message)
            
         
        elif attribute_selection.get()=="k_fold":
            X = df.iloc[:,:-1]
            y = df.iloc[:,-1]
            k = int((testSize)*10)
#             k=3
            global kfold
            kfold =KFold(n_splits=k, random_state=None, shuffle=True)
            for train_index, test_index in kfold.split(X): 
                X_train , X_test = X.iloc[train_index, : ],X.iloc[test_index, : ]
                y_train , y_test = y[train_index] , y[test_index]
            #global model
            model=LinearRegression()
            model.fit(X_train,y_train)
            error_message = " train is done"
            t_train.delete("1.0", "end")
            t_train.insert(END, error_message)
    def test_data():
        if not len(t_train.get("1.0", 'end-1c')):
            error_message = "Train the Model First!"
            t_train.delete("1.0", "end")
            t_train.insert(END, error_message)
            return
        global pred
        pred = model.predict(X_test)
        error_message = " test is done"
        t_train.delete("1.0", "end")
        t_train.insert(END, error_message)
    def res():
        train_data()
        test_data()
        pop=Toplevel()
        pop.geometry("400x400")
        pop.title("Results")
        lbl=Label(pop,text="RMSE: "+ str(metrics.mean_squared_error(pred,y_test)))
        lbl.pack()

        pop.mainloop()
        
    LabelFrame1=LabelFrame(new,text="Loading data")
    LabelFrame1.pack(fill="both",ipadx=5,ipady=5)
    l1=Label(LabelFrame1, text='Select Data File')
    l1.grid(row=0, column=0)
    e1=Entry(LabelFrame1,text='')
    e1.grid(row=0, column=1)

    Button(LabelFrame1,text='open', command=data,bg="#9F2B68",fg="white").grid(row=0, column=2)


    paramFrame=LabelFrame(new,text="Parameters")
    paramFrame.pack(fill="both")
    trainLabel=Label(paramFrame, text='train method:')
    trainLabel.grid(row=1,column=0,pady=10,padx=10)
    OPTIONS = [
        "hold_out_method",
         "k_fold" ]
    attribute_selection = StringVar()
    attribute_selection.set(OPTIONS[0])

    trainFunc=OptionMenu(paramFrame, attribute_selection, *OPTIONS)
    trainFunc.grid(row=1,column=1,pady=10)



    Button(paramFrame, text='Train', command=train_data,bg="#9F2B68",fg="white").grid(row=3,column=2)
    Button(paramFrame, text='Test',command=test_data,bg="#9F2B68",fg="white").grid(row=3,column=3)

    splitLabel=Label(paramFrame, text='Test size:')
    splitLabel.grid(row=3,column=0,padx=10,pady=10)

    splitEntry=Entry(paramFrame)
    splitEntry.grid(row=3, column=1,padx=10,pady=10)

    Button(new, text='Result', command=res,bg="#9F2B68",fg="white").place(x=230,y=230)
    Button(new, text='Close', command=new.destroy,bg="#9F2B68",fg="white").place(x=300,y=230)


    t_upload = Text(new, width=24, height=1)
    t_train = Text(new, width=24, height=1)

    t_upload.place(x=280, y=18)
    t_train.place(x=280, y=90)  
############################################################## 

def plots():
    new=Toplevel(myframe)
    new.geometry("800x600")
    new.title("Plots")
    
    Button(new, text="Heatmap",bg="#9F2B68",font="Helvatica 15 bold",fg="white",command=hplot).place(x=355,y=140)
    Button(new, text="Gender plot",bg="#9F2B68",font="Helvatica 15 bold",fg="white",command=sexplot).place(x=340,y=190)
    Button(new, text="Restecg plot",bg="#9F2B68",font="Helvatica 15 bold",fg="white",command=resplot).place(x=335,y=240)
    Button(new, text="CA plot",bg="#9F2B68",font="Helvatica 15 bold",fg="white",command=caplot).place(x=355,y=290)
    Button(new, text="FBS plot",bg="#9F2B68",font="Helvatica 15 bold",fg="white",command=fbsplot).place(x=350,y=340)
    Button(new, text="Chest Pain",bg="#9F2B68",font="Helvatica 15 bold",fg="white",command=chplot).place(x=340,y=390)
    
    
def open_win():
    new1=Toplevel(myframe)
    new1.geometry("800x750")
    new1.title("rfe")
    
    def data():
        global filename
        filename = askopenfilename(initialdir=r'C:/Users/Softlaptop/ML project',title = "Select file")
        e1.insert(0, filename)
        e1.config(text=filename)

        global file
        file = pd.read_csv(filename)
        for i in file.columns:
            box1.insert(END,i)
    def model():
        x = file.iloc[:,:-1]
        y = file.iloc[:,-1]

        model=svm.SVR(kernel = "linear")
        rfe = RFE(model , n_features_to_select = 5)
        rfe = rfe.fit(x,y)
        filter = rfe.support_
        ranking = rfe.ranking_
   
        print(filter)
        print(ranking)
        data = x[x.columns[filter]]
        data.iloc[:,-1] = y
        data.to_csv("newdata.csv" , index=False)

    l1=Label(new1, text='Select Data File')
    l1.grid(row=0, column=0)
    e1 = Entry(new1,text='')
    e1.grid(row=0, column=1)
    Button(new1,text='open', command=data,bg="#9F2B68",fg="white",activebackground="black").grid(row=0, column=2)
    box1 = Listbox(new1,selectmode='multiple')
    box1.place(x=330,y=50)
    Button(new1,text="Recursive feature elimination",command=model,bg="#9F2B68",fg="white",activebackground="black").place(x=305,y=250)
    Button(new1, text="next>>",font="system",command=newwin).place(x=360,y=340)    

mybutton=Button(myframe, text="Classification", bg="#9F2B68",font="Helvatica 15 bold",fg="white",command=open_win).place(x=330,y=140)
mybutton=Button(myframe, text="Linear Regression",bg="#9F2B68",font="Helvatica 15 bold",fg="white",command=linear_regression).place(x=305,y=190)
mybutton=Button(myframe, text="Visualization",bg="#9F2B68",font="Helvatica 15 bold",fg="white",command=plots).place(x=330,y=240)



def newwin():
    new2=Toplevel(myframe)
    new2.geometry("800x600")
    new2.title("Algorithms")
   
    Label(new2, text="Algorithm",font="Helvatica 15 bold").place(x=350,y=75)

    Button(new2,text='K-Neighbors Classifier',command=KNN,activebackground="black",bg="#9F2B68",fg="white").place(x=330,y=180)
    Button(new2,text='SVM Classifier',command=SVM,activebackground="black",bg="#9F2B68",fg="white").place(x=350,y=280)
    Button(new2,text='DecisionTree Classifier',command=DecCls,activebackground="black",bg="#9F2B68",fg="white").place(x=330,y=230)
#################################################################################
def SVM():
    new3=Toplevel(myframe)
    new3.geometry("600x300")
    new3.title("svm Classifier GUI")
    def data():
        global df
        global check
        filename = askopenfilename(initialdir='C:/Users/Softlaptop/ML project',title = "Select file") 
        check = StringVar()
        check = "Dataset is uploaded"
        file = open(filename, 'r')
        t_upload.insert(END, check)
        df = pd.read_csv(filename)
    def train_data():
        testSize=float(splitEntry.get())
        try:
            testSize=float(splitEntry.get())
        except ValueError:
            print('Test Size value is not a float')
        if attribute_selection.get()=="hold_out_method":
            X = df.iloc[:,:-1]
            y = df.iloc[:,-1]
    
            global X_train, X_test, y_train, y_test 
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=testSize, random_state=42)
        elif attribute_selection.get()=="k_fold":
            X = df.iloc[:,:-1]
            y = df.iloc[:,-1]
            k = int(splitEntry.get())*10
#             k=3
            global kfold
            kfold =KFold(n_splits=k, random_state=None, shuffle=True)
            for train_index, test_index in kfold.split(X): 
                X_train , X_test = X.iloc[train_index, : ],X.iloc[test_index, : ]
                y_train , y_test = y[train_index] , y[test_index]
        if attribute_selection.get()=="linear":
            global clf
            clf=svm.SVC(kernel=attribute_selection.get())
        else:
            clf = svm.SVC(kernel=attribute_selection.get())
        clf = clf.fit(X_train, y_train)
        error_message = " train is done"
        t_train.delete("1.0", "end")
        t_train.insert(END, error_message)
    def test_data():
        if not len(t_train.get("1.0", 'end-1c')):
            error_message = "Train the Model First!"
            t_train.delete("1.0", "end")
            t_train.insert(END, error_message)
            return
        global pred
        pred = clf.predict(X_test)
        error_message = " test is done"
        t_train.delete("1.0", "end")
        t_train.insert(END, error_message)
    def res():
        train_data()
        test_data()
        pop=Toplevel()
        pop.geometry("400x400")
        pop.title("Results")
        lbl=Label(pop,text="Accuracy: "+ str(metrics.accuracy_score(y_test,pred)))
        lbl.pack()
        lbl1=Label(pop,text="Precision: "+ str(metrics.precision_score(y_test, pred)))
        lbl1.pack()
        lbl2=Label(pop,text="Recall: "+ str(metrics.recall_score(y_test, pred)))
        lbl2.pack()
        lbl6=Label(pop,text="F1 score: "+ str(metrics.f1_score(y_test,pred)))
        lbl6.pack()
        lbl7=Label(pop,text="Confusion_matrix "+ str(metrics.confusion_matrix(y_test,pred)))
        lbl7.pack()
        pop.mainloop()


    LabelFrame1=LabelFrame(new3,text="Loading data")
    LabelFrame1.pack(fill="both",ipadx=5,ipady=5)
    l1=Label(LabelFrame1, text='Select Data File')
    l1.grid(row=0, column=0)
    e1=Entry(LabelFrame1,text='')
    e1.grid(row=0, column=1)

    Button(LabelFrame1,text='open',bg="#9F2B68",fg="white" ,command=data).grid(row=0, column=2)


    paramFrame=LabelFrame(new3,text="Parameters")
    paramFrame.pack(fill="both")
    trainLabel=Label(paramFrame, text='train method:')
    trainLabel.grid(row=0,column=0,pady=10,padx=10)
    OPTIONS = [
        "hold_out_method",
         "k_fold" ]
    attribute_selection = StringVar()
    attribute_selection.set(OPTIONS[0])

    trainFunc=OptionMenu(paramFrame, attribute_selection, *OPTIONS)
    trainFunc.grid(row=1,column=1,pady=10)



    kerneLabel=Label(paramFrame, text='Kernel Func:')
    kerneLabel.grid(row=1,column=2,pady=10,padx=10)

    OPTIONS = [
    "Select model",
    "linear",
    "rbf"
    ]

    attribute_selection = StringVar()
    attribute_selection.set(OPTIONS[0])

    kernelFunc=OptionMenu(paramFrame, attribute_selection, *OPTIONS)
    kernelFunc.grid(row=1,column=3,pady=10)

    
    Button(paramFrame, text='Train',bg="#9F2B68",fg="white", command=train_data).grid(row=3,column=2)
    Button(paramFrame, text='Test',bg="#9F2B68",fg="white",command=test_data).grid(row=3,column=3)

    splitLabel=Label(paramFrame, text='Test size:')
    splitLabel.grid(row=3,column=0,padx=10,pady=10)

    splitEntry=Entry(paramFrame)
    splitEntry.grid(row=3, column=1,padx=10,pady=10)

    Button(new3, text='Result',bg="#9F2B68",fg="white", command=res).place(x=230,y=230)
    Button(new3, text='Close', bg="#9F2B68",fg="white",command=new3.destroy).place(x=300,y=230)


    t_upload = Text(new3, width=24, height=1)
    t_train = Text(new3, width=18, height=1)
    
    t_upload.place(x=280, y=18)
    t_train.place(x=430, y=175)
#############################################################################################
def KNN():
    new4=Toplevel(myframe)
    new4.geometry("800x750")
    new4.title("K-Neighbors Classifier")
   
    def data():
        global df
        global check
        filename = askopenfilename(initialdir='C:/Users/Softlaptop/ML project',title = "Select file") 
        check = StringVar()
        check = "Dataset is uploaded"
        file = open(filename, 'r')
        t_upload.insert(END, check)
        df = pd.read_csv(filename)
    def train_data():
        testSize=float(splitEntry.get())
        try:
            testSize=float(splitEntry.get())
        except ValueError:
            print('Test Size value is not a float')
        if attribute_selection.get()=="hold_out_method":
            X = df.iloc[:,:-1]
            y = df.iloc[:,-1]
            global X_train, X_test, y_train, y_test 
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=testSize, random_state=42)
        elif attribute_selection.get()=="k_fold":
            X = df.iloc[:,:-1]
            y = df.iloc[:,-1]
            k = int(splitEntry.get())*10

            
#             k=3
            global kfold
            kfold =KFold(n_splits=k, random_state=None, shuffle=True)
            for train_index, test_index in kfold.split(X): 
                X_train , X_test = X.iloc[train_index, : ],X.iloc[test_index, : ]
                y_train , y_test = y[train_index] , y[test_index]
        global model
        if e7.get() =='':
            error_message = " You must fill k_value ! "
            t_kvalue.delete("1.0", "end")
            t_kvalue.insert(END, error_message)

            
        model = KNeighborsClassifier(n_neighbors=int(e7.get()))
        model= model.fit(X_train, y_train)
        error_message = " train is done"
        t_train.delete("1.0", "end")
        t_train.insert(END, error_message)
    def test_data():
        if not len(t_train.get("1.0", 'end-1c')):
            error_message = "Train the Model First!"
            t_train.delete("1.0", "end")
            t_train.insert(END, error_message)
            return
        global pred
        pred = model.predict(X_test)
        error_message = " test is done"
        t_train.delete("1.0", "end")
        t_train.insert(END, error_message)
    def res():
        train_data()
        test_data()
        pop=Toplevel()
        pop.geometry("400x400")
        pop.title("Results")
        lbl=Label(pop,text="Accuracy: "+ str(metrics.accuracy_score(y_test,pred)))
        lbl.pack()
        lbl1=Label(pop,text="Precision: "+ str(metrics.precision_score(y_test, pred)))
        lbl1.pack()
        lbl2=Label(pop,text="Recall: "+ str(metrics.recall_score(y_test, pred)))
        lbl2.pack()
        lbl6=Label(pop,text="F1 score: "+ str(metrics.f1_score(y_test,pred)))
        lbl6.pack()
        lbl7=Label(pop,text="Confusion_matrix "+ str(metrics.confusion_matrix(y_test,pred)))
        lbl7.pack()
        pop.mainloop()


    LabelFrame1=LabelFrame(new4,text="Loading data")
    LabelFrame1.pack(fill="both",ipadx=5,ipady=5)
    
    l1=Label(LabelFrame1, text='Select Data File')
    l1.grid(row=0, column=0)
    e1=Entry(LabelFrame1,text='')
    e1.grid(row=0, column=1)
    
    l2=Label(LabelFrame1, text='choose k ')
    l2.grid(row=1, column=0)
#     global e7
    e7=Entry(LabelFrame1,text='')
    e7.grid(row=1, column=1)

    Button(LabelFrame1,text='open',bg="#9F2B68",fg="white" ,command=data).grid(row=0, column=2)


    paramFrame=LabelFrame(new4,text="Parameters")
    paramFrame.pack(fill="both")
    
    trainLabel=Label(paramFrame, text='train method:')
    trainLabel.grid(row=1,column=0,pady=10,padx=10)
    OPTIONS = [
        "hold_out_method",
         "k_fold"]
    attribute_selection = StringVar()
    attribute_selection.set(OPTIONS[0])

    trainFunc=OptionMenu(paramFrame, attribute_selection, *OPTIONS)
    trainFunc.grid(row=1,column=1,pady=10)



    Button(paramFrame, text='Train', bg="#9F2B68",fg="white",command=train_data).grid(row=3,column=2)
    Button(paramFrame, text='Test',bg="#9F2B68",fg="white",command=test_data).grid(row=3,column=3)

    splitLabel=Label(paramFrame, text='Test size:')
    splitLabel.grid(row=3,column=0,padx=10,pady=10)
 
    splitEntry=Entry(paramFrame)
    splitEntry.grid(row=3, column=1,padx=10,pady=10)

    Button(new4, text='Result', bg="#9F2B68",fg="white",command=res).place(x=230,y=230)
    Button(new4, text='Close',bg="#9F2B68",fg="white" ,command=new4.destroy).place(x=300,y=230)


    t_upload = Text(new4, width=24, height=1)
    t_train = Text(new4, width=24, height=1)
    t_kvalue = Text(new4, width=24, height=1)

    t_upload.place(x=280, y=18)
    t_train.place(x=380, y=154)
    t_kvalue.place(x=280, y=45)
    
####################################################################################3
def DecCls():
    new5=Toplevel(myframe)
    new5.geometry("600x300")
    new5.title("DT Classifier GUI")
    
    def data():
        global df
        global check
        filename = askopenfilename(initialdir='C:/Users/Softlaptop/ML project',title = "Select file") 
        check = StringVar()
        check = "Dataset is uploaded"
        file = open(filename, 'r')
        t_upload.insert(END, check)
        df = pd.read_csv(filename)
    def train_data():
        testSize=float(splitEntry.get())
        try:
            testSize=float(splitEntry.get())
        except ValueError:
            print('Test Size value is not a float')
        if attribute_selection.get()=="hold_out_method":
            X = df.iloc[:,:-1]
            y = df.iloc[:,-1]
    
            global X_train, X_test, y_train, y_test 
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=testSize, random_state=42)
        elif attribute_selection.get()=="k_fold":
            X = df.iloc[:,:-1]
            y = df.iloc[:,-1]
            k = int(splitEntry.get())*10
#             k=3
            global kfold
            kfold =KFold(n_splits=k, random_state=None, shuffle=True)
            for train_index, test_index in kfold.split(X): 
                X_train , X_test = X.iloc[train_index, : ],X.iloc[test_index, : ]
                y_train , y_test = y[train_index] , y[test_index]
    
        if attribute_selection.get()=="gini":
            global clf
            clf=DecisionTreeClassifier(max_depth=3)
        else:
            clf=DecisionTreeClassifier()
        clf = clf.fit(X_train, y_train)
        error_message = " train is done"
        t_train.delete("1.0", "end")
        t_train.insert(END, error_message)
    def test_data():
        if not len(t_train.get("1.0", 'end-1c')):
            error_message = "Train the Model First!"
            t_train.delete("1.0", "end")
            t_train.insert(END, error_message)
            return
        global pred
        pred = clf.predict(X_test)
        error_message = " test is done"
        t_train.delete("1.0", "end")
        t_train.insert(END, error_message)
    def res():
        train_data()
        test_data()
        pop=Toplevel()
        pop.geometry("400x400")
        pop.title("Results")
        lbl=Label(pop,text="Accuracy: "+ str(metrics.accuracy_score(y_test,pred)))
        lbl.pack()
        lbl1=Label(pop,text="Precision: "+ str(metrics.precision_score(y_test, pred)))
        lbl1.pack()
        lbl2=Label(pop,text="Recall: "+ str(metrics.recall_score(y_test, pred)))
        lbl2.pack()
        lbl6=Label(pop,text="F1 score: "+ str(metrics.f1_score(y_test,pred)))
        lbl6.pack()
        lbl7=Label(pop,text="Confusion_matrix "+ str(metrics.confusion_matrix(y_test,pred)))
        lbl7.pack()
        plt.figure(figsize=(12,12))
        tree.plot_tree(clf, fontsize=6)
        plt.savefig('tree_high_dpi' , dpi=100)
        plt.show()
        pop.mainloop()


    LabelFrame1=LabelFrame(new5,text="Loading data")
    LabelFrame1.pack(fill="both",ipadx=5,ipady=5)
    l1=Label(LabelFrame1, text='Select Data File')
    l1.grid(row=0, column=0)
    e1=Entry(LabelFrame1,text='')
    e1.grid(row=0, column=1)
 
    Button(LabelFrame1,text='open',bg="#9F2B68",fg="white" ,command=data).grid(row=0, column=2)


    paramFrame=LabelFrame(new5,text="Parameters")
    paramFrame.pack(fill="both")
    trainLabel=Label(paramFrame, text='train method:')
    trainLabel.grid(row=1,column=0,pady=10,padx=10)
    OPTIONS = [
        "hold_out_method",
         "k_fold" ]
    attribute_selection = StringVar()
    attribute_selection.set(OPTIONS[0])

    trainFunc=OptionMenu(paramFrame, attribute_selection, *OPTIONS)
    trainFunc.grid(row=1,column=1,pady=10)

    kerneLabel=Label(paramFrame, text='Kernel Func:')
    kerneLabel.grid(row=1,column=2,pady=10,padx=10)

    OPTIONS = [
    "Select model",
    "gini",
    "entropy"
    ]

    attribute_selection = StringVar()
    attribute_selection.set(OPTIONS[0])

    kernelFunc=OptionMenu(paramFrame, attribute_selection, *OPTIONS)
    kernelFunc.grid(row=1,column=3,pady=10)

    Button(paramFrame, text='Train', command=train_data).grid(row=2,column=2)
    Button(paramFrame, text='Test',command=test_data).grid(row=2,column=3)

    splitLabel=Label(paramFrame, text='Test size:')
    splitLabel.grid(row=2,column=0,padx=10,pady=10)

    splitEntry=Entry(paramFrame)
    splitEntry.grid(row=2, column=1,padx=10,pady=10)

    Button(new5, text='Result',bg="#9F2B68",fg="white" ,command=res).place(x=230,y=230)
    Button(new5, text='Close',bg="#9F2B68" ,fg="white",command=new5.destroy).place(x=300,y=230)


    t_upload = Text(new5, width=24, height=1)
    t_train = Text(new5, width=18, height=1)

    t_upload.place(x=280, y=18)
    t_train.place(x=430, y=135)
    

myframe.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\programs\anaconda\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\Softlaptop\AppData\Local\Temp\ipykernel_8684\1807076774.py", line 486, in train_data
#     clf = clf.fit(X_train, y_train)
# NameError: name 'X_train' is not defined
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\programs\anaconda\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\Softlaptop\AppData\Local\Temp\ipykernel_8684\1807076774.py", line 486, in train_data
#     clf = clf.fit(X_train, y_train)
# NameError: name 'X_train' is not defined
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\programs\anaconda\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
# ...
